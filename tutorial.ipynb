# %%
from postgkyl.pgkyl import cli
cli(
    "/Users/ahoffman/personal_gkyl_scripts/sim_data/3x2v/gk_tcv_adapt_src/rt_gk_tcv_nt_iwl_3x2v_p1-ion_M2_5.gkyl gk-rz -n /Users/ahoffman/gkeyll_main/gkeyll/rt_gk_tcv.o/3x2v/rt_gk_tcv_iwl_adapt_source_3x2v_p1-geo_int_mapc2p.gkyl pl -a".split(), 
    standalone_mode=False)

# %%
from postgkyl.api import PgkylSession
pg = PgkylSession()
pg.load(
    "/Users/ahoffman/personal_gkyl_scripts/sim_data/3x2v/gk_tcv_adapt_src/rt_gk_tcv_nt_iwl_3x2v_p1-ion_M0_0.gkyl"
)
pg.gk_rz(
    mapc2p="/Users/ahoffman/gkeyll_main/gkeyll/rt_gk_tcv.o/3x2v/rt_gk_tcv_iwl_adapt_source_3x2v_p1-geo_int_mapc2p_48x32x16.gkyl",
    nz_interp=16,
)
pg.plot(fixaspect=True,
        showgrid=False,
        figsize="5,5")

# %%
from postgkyl.api import PgkylSession
pg = PgkylSession()
pg.load(
    "/Users/ahoffman/personal_gkyl_scripts/sim_data/3x2v/gk_tcv_adapt_src/rt_gk_tcv_nt_iwl_3x2v_p1-ion_M0_0.gkyl"
)
pg.interpolate()
pg.select(z2=31)
pg.plot(
    xlabel=r'$R-R_{lcfs}$ [m]',
    ylabel=r'$y$ [m]',
    clabel=r'$n_i$ [m$^{-3}$]',
    logz=True,
    cmap="twilight",
)

# %%
from postgkyl.api import PgkylSession
pg = PgkylSession()
pg.load(
    "/Users/ahoffman/personal_gkyl_scripts/sim_data/3x2v/gk_tcv_adapt_src/rt_gk_tcv_nt_iwl_3x2v_p1-ion_M0_0.gkyl"
)
pg.interpolate()
pg.select(z2=31)
pg.plot(
    xlabel=r'$R-R_{lcfs}$ [m]',
    ylabel=r'$y$ [m]',
    clabel=r'$n_i$ [m$^{-3}$]',
    logz=True,
    cmap="twilight",
)
